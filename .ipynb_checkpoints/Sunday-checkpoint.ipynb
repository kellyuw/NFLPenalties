# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np
import nflgame
import os
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

#Setting for displaying inline graphics with matplotlib
# %matplotlib inline

# %%
print gd
# Out:
#       HScore  HVScoreDiff       NDate  Season  VScore Winner VTeam  day  \
# 0         13            3   9/10/2009    2009      10    PIT   TEN   10
# 1         19           12   9/13/2009    2009       7    ATL   MIA   13
# 2         38           14   9/13/2009    2009      24    BAL    KC   13
# 3         10          -28   9/13/2009    2009      38    PHI   PHI   13
# 4          7           -5   9/13/2009    2009      12    DEN   DEN   13
# 5         20          -14   9/13/2009    2009      34    MIN   MIN   13
# 6          7          -17   9/13/2009    2009      24    NYJ   NYJ   13
# 7         14            2   9/13/2009    2009      12    IND   JAC   13
# 8         45           18   9/13/2009    2009      27     NO   DET   13
# 9         21          -13   9/13/2009    2009      34    DAL   DAL   13
# 10        16           -4   9/13/2009    2009      20     SF    SF   13
# 11        23            6   9/13/2009    2009      17    NYG   WAS   13
# 12        28           28   9/13/2009    2009       0    SEA   STL   13
# 13        21            6   9/13/2009    2009      15     GB   CHI   13
# 14        25            1   9/14/2009    2009      24     NE   BUF   14
# 15        20           -4   9/14/2009    2009      24     SD    SD   14
# 16        28            8   9/20/2009    2009      20    ATL   CAR   20
# 17        13          -14   9/20/2009    2009      27    MIN   MIN   20
# 18        24           -7   9/20/2009    2009      31    CIN   CIN   20
# 19        17          -14   9/20/2009    2009      31    ARI   ARI   20
# 20        10           -3   9/20/2009    2009      13    OAK   OAK   20
# 21        16            7   9/20/2009    2009       9    NYJ    NE   20
# 22        22          -26   9/20/2009    2009      48     NO    NO   20
# 23        31           -3   9/20/2009    2009      34    HOU   HOU   20
# 24         9            2   9/20/2009    2009       7    WAS   STL   20
# 25        33           13   9/20/2009    2009      20    BUF    TB   20
# 26        23           13   9/20/2009    2009      10     SF   SEA   20
# 27        17            3   9/20/2009    2009      14    CHI   PIT   20
# 28        27           21   9/20/2009    2009       6    DEN   CLE   20
# 29        26           -5   9/20/2009    2009      31    BAL   BAL   20
# ...      ...          ...         ...     ...     ...    ...   ...  ...
# 1762      38           11  12/27/2015    2015      27     NO   JAC   27
# 1763      12           -6  12/27/2015    2015      18    IND   IND   27
# 1764      26            6  12/27/2015    2015      20    NYJ    NE   27
# 1765       6          -28  12/27/2015    2015      34    HOU   HOU   27
# 1766      17            4  12/27/2015    2015      13     KC   CLE   27
# 1767      32           15  12/27/2015    2015      17    DET    SF   27
# 1768      49           32  12/27/2015    2015      17    MIN   NYG   27
# 1769      20            7  12/27/2015    2015      13    ATL   CAR   27
# 1770      21           -5  12/27/2015    2015      26    CHI   CHI   27
# 1771      16           10  12/27/2015    2015       6    BUF   DAL   27
# 1772      38           30  12/27/2015    2015       8    ARI    GB   27
# 1773      17           -6  12/27/2015    2015      23    STL   STL   27
# 1774      20            3  12/27/2015    2015      17    BAL   PIT   27
# 1775      20            3  12/28/2015    2015      17    DEN   CIN   28
# 1776      22            5    1/3/2015    2015      17    BUF   NYJ    3
# 1777      20           10    1/3/2015    2015      10    MIA    NE    3
# 1778      24            8    1/3/2015    2015      16    CIN   BAL    3
# 1779      12          -16    1/3/2015    2015      28    PIT   PIT    3
# 1780      30           24    1/3/2015    2015       6    HOU   JAC    3
# 1781      30            6    1/3/2015    2015      24    IND   TEN    3
# 1782      23            6    1/3/2015    2015      17     KC   OAK    3
# 1783      23          -11    1/3/2015    2015      34    WAS   WAS    3
# 1784      30           -5    1/3/2015    2015      35    PHI   PHI    3
# 1785      20           -4    1/3/2015    2015      24    DET   DET    3
# 1786      13           -7    1/3/2015    2015      20    MIN   MIN    3
# 1787      17           -3    1/3/2015    2015      20     NO    NO    3
# 1788      38           28    1/3/2015    2015      10    CAR    TB    3
# 1789      27            7    1/3/2015    2015      20    DEN    SD    3
# 1790       6          -30    1/3/2015    2015      36    SEA   SEA    3
# 1791      19            3    1/3/2015    2015      16     SF   STL    3
#
#              eid  gamekey HTeam  month gametype   time wday  week  year
# 0     2009091000    54467   PIT      9      REG   8:30  Thu     1  2009
# 1     2009091300    54468   ATL      9      REG   1:00  Sun     1  2009
# 2     2009091301    54469   BAL      9      REG   1:00  Sun     1  2009
# 3     2009091302    54470   CAR      9      REG   1:00  Sun     1  2009
# 4     2009091303    54471   CIN      9      REG   1:00  Sun     1  2009
# 5     2009091304    54472   CLE      9      REG   1:00  Sun     1  2009
# 6     2009091305    54473   HOU      9      REG   1:00  Sun     1  2009
# 7     2009091306    54474   IND      9      REG   1:00  Sun     1  2009
# 8     2009091307    54475    NO      9      REG   1:00  Sun     1  2009
# 9     2009091308    54476    TB      9      REG   1:00  Sun     1  2009
# 10    2009091309    54477   ARI      9      REG   4:15  Sun     1  2009
# 11    2009091310    54478   NYG      9      REG   4:15  Sun     1  2009
# 12    2009091311    54479   SEA      9      REG   4:15  Sun     1  2009
# 13    2009091312    54480    GB      9      REG   8:20  Sun     1  2009
# 14    2009091400    54481    NE      9      REG   7:00  Mon     1  2009
# 15    2009091401    54482   OAK      9      REG  10:15  Mon     1  2009
# 16    2009092000    54483   ATL      9      REG   1:00  Sun     2  2009
# 17    2009092001    54484   DET      9      REG   1:00  Sun     2  2009
# 18    2009092002    54485    GB      9      REG   1:00  Sun     2  2009
# 19    2009092003    54486   JAC      9      REG   1:00  Sun     2  2009
# 20    2009092004    54487    KC      9      REG   1:00  Sun     2  2009
# 21    2009092005    54488   NYJ      9      REG   1:00  Sun     2  2009
# 22    2009092006    54489   PHI      9      REG   1:00  Sun     2  2009
# 23    2009092007    54490   TEN      9      REG   1:00  Sun     2  2009
# 24    2009092008    54491   WAS      9      REG   1:00  Sun     2  2009
# 25    2009092009    54492   BUF      9      REG   4:05  Sun     2  2009
# 26    2009092010    54493    SF      9      REG   4:05  Sun     2  2009
# 27    2009092011    54494   CHI      9      REG   4:15  Sun     2  2009
# 28    2009092012    54495   DEN      9      REG   4:15  Sun     2  2009
# 29    2009092013    54496    SD      9      REG   4:15  Sun     2  2009
# ...          ...      ...   ...    ...      ...    ...  ...   ...   ...
# 1762  2015122700    56735    NO     12      REG   4:05  Sun    16  2015
# 1763  2015122701    56733   MIA     12      REG   1:00  Sun    16  2015
# 1764  2015122702    56736   NYJ     12      REG   1:00  Sun    16  2015
# 1765  2015122703    56738   TEN     12      REG   1:00  Sun    16  2015
# 1766  2015122704    56732    KC     12      REG   1:00  Sun    16  2015
# 1767  2015122705    56731   DET     12      REG   1:00  Sun    16  2015
# 1768  2015122706    56734   MIN     12      REG   8:30  Sun    16  2015
# 1769  2015122707    56729   ATL     12      REG   1:00  Sun    16  2015
# 1770  2015122708    56737    TB     12      REG   1:00  Sun    16  2015
# 1771  2015122709    56730   BUF     12      REG   1:00  Sun    16  2015
# 1772  2015122710    56739   ARI     12      REG   4:25  Sun    16  2015
# 1773  2015122711    56740   SEA     12      REG   4:25  Sun    16  2015
# 1774  2015122712    56741   BAL     12      REG   1:00  Sun    16  2015
# 1775  2015122800    56742   DEN     12      REG   8:30  Mon    16  2015
# 1776  2016010300    56744   BUF      1      REG   1:00  Sun    17  2015
# 1777  2016010301    56754   MIA      1      REG   1:00  Sun    17  2015
# 1778  2016010302    56747   CIN      1      REG   1:00  Sun    17  2015
# 1779  2016010303    56748   CLE      1      REG   1:00  Sun    17  2015
# 1780  2016010304    56751   HOU      1      REG   1:00  Sun    17  2015
# 1781  2016010305    56752   IND      1      REG   1:00  Sun    17  2015
# 1782  2016010306    56753    KC      1      REG   4:25  Sun    17  2015
# 1783  2016010307    56749   DAL      1      REG   1:00  Sun    17  2015
# 1784  2016010308    56755   NYG      1      REG   1:00  Sun    17  2015
# 1785  2016010309    56746   CHI      1      REG   1:00  Sun    17  2015
# 1786  2016010310    56750    GB      1      REG   8:30  Sun    17  2015
# 1787  2016010311    56743   ATL      1      REG   1:00  Sun    17  2015
# 1788  2016010312    56745   CAR      1      REG   4:25  Sun    17  2015
# 1789  2016010313    56757   DEN      1      REG   4:25  Sun    17  2015
# 1790  2016010314    56756   ARI      1      REG   4:25  Sun    17  2015
# 1791  2016010315    56758    SF      1      REG   4:25  Sun    17  2015
#
# [1792 rows x 17 columns]

# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np
import nflgame
import os
import seaborn as sns
import matplotlib.pyplot as plt


#Custom color palettes for graphs
custompal = ["#F44336","#E91E63","#9C27B0","#673AB7","#3F51B5","#2196F3","#03A9F4","#00BCD4","#009688","#4CAF50",
             "#8BC34A","#CDDC39","#FFEB3B","#FFC107","#FF9800","#FF5722","#795548","#9E9E9E","#607D8B"]
minicustom = custompal[::2]
sns.set_palette(minicustom)
#sns.palplot(custompal)

sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))
teams = ['buffalo-bills', 'miami-dolphins', 'new-england-patriots', 'new-york-jets', 'baltimore-ravens',
         'cincinnati-bengals', 'cleveland-browns', 'pittsburgh-steelers', 'houston-texans', 'indianapolis-colts',
         'jacksonville-jaguars', 'tennessee-titans', 'denver-broncos', 'kansas-city-chiefs', 'oakland-raiders',
         'san-diego-chargers', 'dallas-cowboys', 'new-york-giants', 'philadelphia-eagles', 'washington-redskins',
         'chicago-bears', 'detroit-lions', 'green-bay-packers', 'minnesota-vikings', 'atlanta-falcons',
         'carolina-panthers', 'new-orleans-saints', 'tampa-bay-buccaneers', 'arizona-cardinals',
         'san-francisco-49ers', 'seattle-seahawks', 'st-louis-rams']

def GetStdTeam(team):
    #Convert team name into easily parsable string
    tm = team.replace('-',' ')

    #Rams no longer in St. Louis (so just use Rams for search)
    if ("rams" in tm):
        tm = "rams"

    #Get standard team name
    stdteam = nflgame.standard_team(str(tm))
    return stdteam


def GetPenaltyData(team, year):
    print 'Getting data for ' + team + ' ' + year

    #Set up url string
    teamfile = 'http://www.nflpenalties.com/team/' + team + '?year=' + year + '&view=log'

    #Set up BeautifulSoup parser
    r = urllib.urlopen(teamfile).read()
    soup = BeautifulSoup(r, "lxml")
    print type(soup)

    #Get content
    content = soup.find_all("div", id="content")

    return content


def ParseContent(content, stdteam):
    tb = content[0].find('tbody')
    y = pd.DataFrame()
    z = ['team','penalty','game','opponent','player','position','week','year','penaltyindex']
    count = 0
    missing = 0

    for row in tb.findAll('tr'):
        missing = str(row).count('></a>')

        if (missing == 0):
            for link in row.findAll('a'):

                href = link['href']
                linkinfo = href.split('/')
                linkcat = str(linkinfo[1])

                linkdetails = str(link.get_text())

                if (linkcat == 'penalty'):
                    t = [stdteam]

                if ('week.php' not in href):
                    t = np.hstack([t, linkdetails])
                else:
                    weekandyear = href.split('week=')[1]
                    week = weekandyear.split('?')[0]
                    year = weekandyear.split('year=')[1]

                    t = np.hstack([t, week, year])

                    penaltyindex = stdteam + '-' + str(year) + '-' + str(count)

                    t = np.hstack([t, penaltyindex])
                    z = np.vstack([z,t])
                    count += 1
        else:
            missing += 1

    totalpenalties = missing + count
    z['opponent'] = z['opponent'].apply(lambda x: GetStdTeam(x))
    return [z,totalpenalties]

#This writes CSV of data for particular team and year
def WritePenaltyData(penalties, stdteam, year, fname):
    totalnumpenalties = penalties[1]
    print stdteam + ',' + year + ',' + str(totalnumpenalties)
    np.savetxt(fname, penalties[0], fmt = '%s', delimiter=',')

#Gets data from all teams into dataframe for particular year
def GetAllTeams(year):
    data = pd.DataFrame()
    for team in teams:
        stdteam = GetStdTeam(team)
        print stdteam
        fname = '/Users/kelly89/NFLPenalties/' + stdteam + year + '.csv'

        if (os.path.isfile(fname) == False):
            content = GetPenaltyData(team, year)
            penalties = ParseContent(content, stdteam)
            WritePenaltyData(penalties, stdteam, year, fname)
        else:
            print 'Found data file for ' + stdteam + ' ' + year

        temp = pd.read_csv(fname, sep = ',')
        data = pd.concat([data,temp], ignore_index = True)
    return data

#Writes main CSV (penalty data fro all teams and all years from 2011-2015)
def GetAllYears(fname):
    alldata = pd.DataFrame()
    for year in ['2011','2012','2013','2014','2015']:
        tempyear = GetAllTeams(year)
        alldata = pd.concat([alldata,tempyear], ignore_index = True)

    alldata.columns = ['Team','Penalty','NDate','Opponent','Player','Position','Week','Year','PenaltyIndex']
    alldata['Opponent'] = alldata['Opponent'].apply(lambda x: GetStdTeam(x))
    d = alldata.dropna()
    d.to_csv(fname, sep = ',', index = False)

def GetRegSeasonRecord (team, year):
    team = str(team)
    year = int(year)

    games = nflgame.games_gen(year, week = None, home = team, away = team, kind = 'REG')
    for g in games:
        print g
        if (g.winner == team):
            w += 1
        elif (g.loser == team):
            l += 1
        else:
            print "ERROR: can not determine winner of this game"

        print 'W-L: ' + str(w) + '-' + str(l)

    return [int(w),int(l)]

def GetAllRefInfo(fname):
    pfr = 'http://www.pro-football-reference.com/officials'
    pfrUrl = urllib.urlopen(pfr).read()
    pfrSoup = BeautifulSoup(pfrUrl, "lxml")
    content = pfrSoup.find_all("div", id="page_content")

    a = content[0].find('table')
    b = pd.DataFrame()
    c = ['webpage','name','games','positions','years']
    count = 0
    m = 0
    e = []

    for row in a.findAll('tr')[1:]:
        m = str(row).count('></td>')
        webpage = os.path.dirname(pfr) + str(row.findNext('a')['href'])
        e = [webpage]
        for val in row.findAll('td'):
            d = val.get_text()
            e = np.hstack([e, str(d)])
        if (len(e) == 5):
            c = np.vstack([c,e])
            count += 1
        else:
            m += 1
    GetAllRefGames(c[1:], fname)

def GetAllRefGames(refinfo, fname):
    refstats = ['ref','exp','date','visitor','home','position','vpen','vpenyd','hpen','hpenyd']

    for ref in refinfo:
        refname = ref[1].rpartition(' ')[2]
        exp = str(ref[2])
        print 'Getting data for ' + refname

        refUrl = urllib.urlopen(ref[0]).read()
        refSoup = BeautifulSoup(refUrl, "lxml")

        i = refSoup.find_all("div", id="div_game_logs")[0]

        for row in i.findAll('tr'):
            j = []
            alltd = row.findAll("td")
            if (len(alltd) != 0):
                date = alltd[0].get_text()
                teams = alltd[1].get_text().split(' @ ')
                v = nflgame.standard_team(teams[0].rpartition(' ')[2])
                h = nflgame.standard_team(teams[1].rpartition(' ')[2])
                pos = alltd[2].get_text().replace(' ','-')
                vpen = alltd[4].get_text()
                vpenyd = alltd[5].get_text()
                hpen = alltd[7].get_text()
                hpenyd = alltd[8].get_text()

                j = np.hstack([refname, exp, date, v, h, pos, vpen, vpenyd, hpen, hpenyd])

                if (len(j) == 10):
                    refstats = np.vstack([refstats, j])
            print refstats
    np.savetxt(fname, refstats, fmt = '%s', delimiter=',')


def NormDate(date):
    d = date.split('-')
    d = str(d[1] + '/' + d[2] + '/' + d[0])
    return str(d)

def MakeKey(r):
    yr = r.NDate.replace('/','-')
    k = str(yr + '-' + r.HTeam)
    return k

def GetHomeTm(r, homeTms):
    if (r.Team in homeTms):
        return r.Team
    else:
        return r.Opponent


def GetAwayTm(r, homeTms):
    if (r.Team not in homeTms):
        return r.Team
    else:
        return r.Opponent

def MergePenaltyAndRefs(fname, data, rd):

    rd['NDate'] = rd['Date'].apply(lambda x: NormDate(x))
    #rd['Year'] = rd['NDate'].apply(lambda x: str(x).split('/')[2])

    #penYears = map(str, range(2011,2016))
    #rd = rd[rd['Year'].isin(penYears)]

    #Add column to determine if player was on home team
    a = rd.groupby(['HTeam', 'NDate'], as_index = False).count()
    data['HTeam'] = data.apply(lambda x: GetHomeTm(x, a[(a['NDate'] == str(x.NDate))]), axis=1)
    data['VTeam'] = data.apply(lambda x: GetAwayTm(x, a[(a['NDate'] == str(x.NDate))]), axis=1)

    #This isn't necessary and sort of hackish. Probably better to multindex?
    rd['key'] = rd.apply(MakeKey, axis=1)
    data['key'] = data.apply(MakeKey, axis=1)

    uniqcols = rd.columns.difference(data.columns)
    newrd = pd.concat([rd[['key']],rd[uniqcols]], axis=1)
    #data = data.set_index('key')
    #rd = rd.set_index('key')
    #newrd = newrd.set_index('key')


    c = pd.merge(data, newrd, left_on = 'key', right_on = 'key')
    #d = c.update(rd)
    print c.shape
    print c.head(40)
    c.to_csv(fname, sep=",", index = False)


def GetGameData(year):
    games = nflgame.games_gen(year)
    a = pd.DataFrame()
    for g in games:
        Schedule = g.schedule
        s = pd.DataFrame.from_dict([Schedule])
        extra = {'HScore': g.score_home, 'VScore': g.score_away, 'Winner': g.winner, 'Season': g.season()}
        e = pd.DataFrame.from_dict([extra])
        r = pd.concat([s, e], axis=1)
        r['HVScoreDiff'] = r['HScore'] - r['VScore']
        r['NDate'] = str(str(r.month[0]) + '/' + str(r.day[0]) + '/' + str(r.year[0]))
        a = pd.concat([a, r])
    return a

def GetAllGameData(fname):
    allyears = pd.DataFrame()
    hdr = ['HScore','HVScoreDiff','NDate','Season','VScore','Winner','VTeam','day','eid','gamekey','HTeam','meridiem','month','gametype','time','wday','week','year']
    for year in range(2009,2016):
        yr = GetGameData(year)
        print 'Getting game data for ' + str(year) + ' season'
        allyears = pd.concat([allyears, yr])
    allyears.columns = [hdr]
    allyears = allyears.drop('meridiem', axis = 1)
    allyears.to_csv(fname, sep=",", index = False)




#Main code

#Get penalty data for all years into dataframe
allPenF = '/Users/kelly89/NFLPenalties/AllPenalties.csv'
if (os.path.isfile(allPenF) == False):
    GetAllYears(allPenF)
else:
    print 'Found ' + allPenF
data = pd.read_csv(allPenF, sep=",")
print data.shape


#Get refdata into dataframe
refDataF = '/Users/kelly89/NFLPenalties/RefData.csv'
if (os.path.isfile(refDataF) == False):
    GetAllRefInfo(refDataF)
else:
    print 'Found ' + refDataF
rd = pd.read_csv(refDataF, sep=",")
rd.columns = ['LastName','Exp','Date','VTeam','HTeam','RefPosition','VPen','VPenYd','HPen','HPenYd']
rd = rd[(rd['RefPosition'] == 'Referee')]
print rd.shape

#Merge ref data with penalty data
refPenF = '/Users/kelly89/NFLPenalties/RefAndPenalties.csv'
if (os.path.isfile(refPenF) == False):
    MergePenaltyAndRefs(refPenF, data, rd)
else:
    print 'Found ' + refPenF
rp = pd.read_csv(refPenF, sep=',')
print rp.shape
print 'rp descriptive stats:'
for c in rp.columns.values:
    n = rp[c].isnull().sum()
    print c + ' ' + str(n)

#Get all game data
gameDataF = '/Users/kelly89/NFLPenalties/AllGameData.csv'
if (os.path.isfile(gameDataF) == False):
    GetAllGameData(gameDataF)
else:
    print 'Found ' + gameDataF
gd = pd.read_csv(gameDataF, sep=',')
print gd.shape
print 'gd descriptive stats:'
for c in gd.columns.values:
    n = gd[c].isnull().sum()
    print c + ' ' + str(n)

#Merge ref, penalty, and gamedata
rfpF = '/Users/kelly89/NFLPenalties/RefPenaltyAndGameData.csv'
if (os.path.isfile(rfpF) == False):
    gd['key'] = gd.apply(lambda x: MakeKey(x), axis=1)
    print 'gd'
    print gd.head(10)
    uniqcols = rd[rp.columns.difference(data.columns),'key']
    #newrp = pd.concat([rp[['key']],rp[uniqcols]], axis=1)
    print 'uniqcols'
    print uniqcols.head(10)
    #m = pd.merge(gd, newrp, left_on = 'key', right_on = 'key', how = 'outer')
    #print m.shape
    #m.to_csv(rfpF, sep = ',', index = False)
else:
    print 'Found ' + rfpF
#rfp = pd.read_csv(rfpF, sep=',')
#print rfp.shape
#print 'rfp descriptive stats:'

#for c in rfp.columns.values:
#    n = rfp[c].isnull().sum()
#    print c + ' ' + str(n)

#sdF = '/Users/kelly89/NFLPenalties/StadiumData.csv'
#sd = pd.read_csv(sdF, sep = ',')
#print sd.shape

#print sd.columns.values
#print rfp.columns.values 

#rfpgsF = '/Users/kelly89/NFLPenalties/RefPenaltyGameAndStadiumData.csv'
#if (os.path.isfile(rfpgsF) == False):
#    m = pd.merge(rfp, sd, left_on = 'HTeam', right_on = 'HTeam')
#    m.to_csv(rfpgsF, sep = ',', index = False)
#else:
#    print 'Found ' + rfpgsF
#f = pd.read_csv(rfpgsF, sep = ',')
#print f.shape
# Out:
# Found /Users/kelly89/NFLPenalties/AllPenalties.csv
# (17682, 9)
# Found /Users/kelly89/NFLPenalties/RefData.csv
# (4515, 10)
# Found /Users/kelly89/NFLPenalties/RefAndPenalties.csv
# (21002, 20)
# rp descriptive stats:
# Team 3320
# Penalty 3320
# NDate 3320
# Opponent 3320
# Player 3320
# Position 3320
# Week 3320
# Year 3320
# PenaltyIndex 3320
# HTeam 3320
# VTeam 3320
# key 0
# Date 8865
# Exp 8865
# HPen 8865
# HPenYd 8865
# LastName 8865
# RefPosition 8865
# VPen 8865
# VPenYd 8865
# Found /Users/kelly89/NFLPenalties/AllGameData.csv
# (1792, 17)
# gd descriptive stats:
# HScore 0
# HVScoreDiff 0
# NDate 0
# Season 0
# VScore 0
# Winner 0
# VTeam 0
# day 0
# eid 0
# gamekey 0
# HTeam 0
# month 0
# gametype 0
# time 0
# wday 0
# week 0
# year 0
# gd
#    HScore  HVScoreDiff      NDate  Season  VScore Winner VTeam  day  \
# 0      13            3  9/10/2009    2009      10    PIT   TEN   10
# 1      19           12  9/13/2009    2009       7    ATL   MIA   13
# 2      38           14  9/13/2009    2009      24    BAL    KC   13
# 3      10          -28  9/13/2009    2009      38    PHI   PHI   13
# 4       7           -5  9/13/2009    2009      12    DEN   DEN   13
# 5      20          -14  9/13/2009    2009      34    MIN   MIN   13
# 6       7          -17  9/13/2009    2009      24    NYJ   NYJ   13
# 7      14            2  9/13/2009    2009      12    IND   JAC   13
# 8      45           18  9/13/2009    2009      27     NO   DET   13
# 9      21          -13  9/13/2009    2009      34    DAL   DAL   13
#
#           eid  gamekey HTeam  month gametype  time wday  week  year  \
# 0  2009091000    54467   PIT      9      REG  8:30  Thu     1  2009
# 1  2009091300    54468   ATL      9      REG  1:00  Sun     1  2009
# 2  2009091301    54469   BAL      9      REG  1:00  Sun     1  2009
# 3  2009091302    54470   CAR      9      REG  1:00  Sun     1  2009
# 4  2009091303    54471   CIN      9      REG  1:00  Sun     1  2009
# 5  2009091304    54472   CLE      9      REG  1:00  Sun     1  2009
# 6  2009091305    54473   HOU      9      REG  1:00  Sun     1  2009
# 7  2009091306    54474   IND      9      REG  1:00  Sun     1  2009
# 8  2009091307    54475    NO      9      REG  1:00  Sun     1  2009
# 9  2009091308    54476    TB      9      REG  1:00  Sun     1  2009
#
#              key
# 0  9-10-2009-PIT
# 1  9-13-2009-ATL
# 2  9-13-2009-BAL
# 3  9-13-2009-CAR
# 4  9-13-2009-CIN
# 5  9-13-2009-CLE
# 6  9-13-2009-HOU
# 7  9-13-2009-IND
# 8   9-13-2009-NO
# 9   9-13-2009-TB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-287-6952678eb690> in <module>()
#     354     print 'gd'
#     355     print gd.head(10)
# --> 356     uniqcols = rd[rp.columns.difference(data.columns)]
#     357     #newrp = pd.concat([rp[['key']],rp[uniqcols]], axis=1)
#     358     print 'uniqcols'
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['key'] not in index"

# %%
print rp
# Out:
#       Team                        Penalty       NDate Opponent         Player  \
# 0      BUF           Face Mask (15 Yards)  09/11/2011       KC        J.White
# 1      BUF                    False Start  09/11/2011       KC        E.Pears
# 2      BUF                    False Start  09/11/2011       KC     C.Rinehart
# 3      BUF                  Delay of Game  09/11/2011       KC  R.Fitzpatrick
# 4      BUF              Defensive Offside  09/11/2011       KC       M.Dareus
# 5      BUF              Offensive Holding  09/11/2011       KC     C.Hairston
# 6      BUF  Illegal Block Above the Waist  09/18/2011      OAK     C.McIntyre
# 7      BUF              Illegal Crackback  09/18/2011      OAK        D.Jones
# 8      BUF        Neutral Zone Infraction  09/18/2011      OAK        K.Heard
# 9      BUF                Illegal Contact  09/18/2011      OAK       G.Wilson
# 10     BUF              Defensive Holding  09/25/2011       NE      N.Barnett
# 11     BUF                     Chop Block  09/25/2011       NE         E.Wood
# 12     BUF              Offensive Holding  09/25/2011       NE         E.Wood
# 13     BUF  Illegal Block Above the Waist  09/25/2011       NE        C.White
# 14     BUF              Offensive Holding  09/25/2011       NE     S.Chandler
# 15     BUF          Unnecessary Roughness  09/25/2011       NE      N.Barnett
# 16     BUF          Unnecessary Roughness  09/25/2011       NE         J.Byrd
# 17     BUF  Illegal Block Above the Waist  09/25/2011       NE       R.Corner
# 18     BUF                    False Start  09/25/2011       NE     C.Rinehart
# 19     BUF                   Encroachment  10/02/2011      CIN    Ky.Williams
# 20     BUF              Offensive Holding  10/02/2011      CIN     D.Florence
# 21     BUF    Offensive Pass Interference  10/02/2011      CIN       D.Nelson
# 22     BUF           Illegal Use of Hands  10/02/2011      CIN     D.Florence
# 23     BUF        Neutral Zone Infraction  10/02/2011      CIN    Ky.Williams
# 24     BUF              Defensive Offside  10/09/2011      PHI    Ky.Williams
# 25     BUF           Face Mask (15 Yards)  10/09/2011      PHI     C.McIntyre
# 26     BUF            Roughing the Passer  10/09/2011      PHI       D.Batten
# 27     BUF                    False Start  10/09/2011      PHI       R.Martin
# 28     BUF              Offensive Holding  10/09/2011      PHI        K.Urbik
# 29     BUF              Offensive Holding  10/30/2011      WAS        K.Urbik
# ...    ...                            ...         ...      ...            ...
# 20972  NaN                            NaN         NaN      NaN            NaN
# 20973  NaN                            NaN         NaN      NaN            NaN
# 20974  NaN                            NaN         NaN      NaN            NaN
# 20975  NaN                            NaN         NaN      NaN            NaN
# 20976  NaN                            NaN         NaN      NaN            NaN
# 20977  NaN                            NaN         NaN      NaN            NaN
# 20978  NaN                            NaN         NaN      NaN            NaN
# 20979  NaN                            NaN         NaN      NaN            NaN
# 20980  NaN                            NaN         NaN      NaN            NaN
# 20981  NaN                            NaN         NaN      NaN            NaN
# 20982  NaN                            NaN         NaN      NaN            NaN
# 20983  NaN                            NaN         NaN      NaN            NaN
# 20984  NaN                            NaN         NaN      NaN            NaN
# 20985  NaN                            NaN         NaN      NaN            NaN
# 20986  NaN                            NaN         NaN      NaN            NaN
# 20987  NaN                            NaN         NaN      NaN            NaN
# 20988  NaN                            NaN         NaN      NaN            NaN
# 20989  NaN                            NaN         NaN      NaN            NaN
# 20990  NaN                            NaN         NaN      NaN            NaN
# 20991  NaN                            NaN         NaN      NaN            NaN
# 20992  NaN                            NaN         NaN      NaN            NaN
# 20993  NaN                            NaN         NaN      NaN            NaN
# 20994  NaN                            NaN         NaN      NaN            NaN
# 20995  NaN                            NaN         NaN      NaN            NaN
# 20996  NaN                            NaN         NaN      NaN            NaN
# 20997  NaN                            NaN         NaN      NaN            NaN
# 20998  NaN                            NaN         NaN      NaN            NaN
# 20999  NaN                            NaN         NaN      NaN            NaN
# 21000  NaN                            NaN         NaN      NaN            NaN
# 21001  NaN                            NaN         NaN      NaN            NaN
#
#       Position  Week  Year PenaltyIndex HTeam VTeam             key  \
# 0           RB     1  2011   BUF-2011-0    KC   BUF   09-11-2011-KC
# 1            T     1  2011   BUF-2011-1    KC   BUF   09-11-2011-KC
# 2            G     1  2011   BUF-2011-2    KC   BUF   09-11-2011-KC
# 3           QB     1  2011   BUF-2011-3    KC   BUF   09-11-2011-KC
# 4           DT     1  2011   BUF-2011-4    KC   BUF   09-11-2011-KC
# 5            T     1  2011   BUF-2011-5    KC   BUF   09-11-2011-KC
# 6           FB     2  2011   BUF-2011-6   OAK   BUF  09-18-2011-OAK
# 7           WR     2  2011   BUF-2011-7   OAK   BUF  09-18-2011-OAK
# 8           DT     2  2011   BUF-2011-8   OAK   BUF  09-18-2011-OAK
# 9           SS     2  2011   BUF-2011-9   OAK   BUF  09-18-2011-OAK
# 10          LB     3  2011  BUF-2011-10    NE   BUF   09-25-2011-NE
# 11           C     3  2011  BUF-2011-11    NE   BUF   09-25-2011-NE
# 12           C     3  2011  BUF-2011-12    NE   BUF   09-25-2011-NE
# 13          LB     3  2011  BUF-2011-13    NE   BUF   09-25-2011-NE
# 14          TE     3  2011  BUF-2011-14    NE   BUF   09-25-2011-NE
# 15          LB     3  2011  BUF-2011-15    NE   BUF   09-25-2011-NE
# 16          FS     3  2011  BUF-2011-16    NE   BUF   09-25-2011-NE
# 17          DB     3  2011  BUF-2011-17    NE   BUF   09-25-2011-NE
# 18           G     3  2011  BUF-2011-18    NE   BUF   09-25-2011-NE
# 19          DT     4  2011  BUF-2011-19   CIN   BUF  10-02-2011-CIN
# 20          DB     4  2011  BUF-2011-20   CIN   BUF  10-02-2011-CIN
# 21          WR     4  2011  BUF-2011-21   CIN   BUF  10-02-2011-CIN
# 22          DB     4  2011  BUF-2011-22   CIN   BUF  10-02-2011-CIN
# 23          DT     4  2011  BUF-2011-23   CIN   BUF  10-02-2011-CIN
# 24          DT     5  2011  BUF-2011-24   PHI   BUF  10-09-2011-PHI
# 25          FB     5  2011  BUF-2011-25   PHI   BUF  10-09-2011-PHI
# 26          LB     5  2011  BUF-2011-26   PHI   BUF  10-09-2011-PHI
# 27          WR     5  2011  BUF-2011-27   PHI   BUF  10-09-2011-PHI
# 28           G     5  2011  BUF-2011-28   PHI   BUF  10-09-2011-PHI
# 29           G     8  2011  BUF-2011-37   WAS   BUF  10-30-2011-WAS
# ...        ...   ...   ...          ...   ...   ...             ...
# 20972      NaN   NaN   NaN          NaN   NaN   NaN  09-16-2002-WAS
# 20973      NaN   NaN   NaN          NaN   NaN   NaN  09-29-2002-OAK
# 20974      NaN   NaN   NaN          NaN   NaN   NaN  10-06-2002-CAR
# 20975      NaN   NaN   NaN          NaN   NaN   NaN  10-13-2002-NYG
# 20976      NaN   NaN   NaN          NaN   NaN   NaN  10-20-2002-BAL
# 20977      NaN   NaN   NaN          NaN   NaN   NaN  10-27-2002-NYJ
# 20978      NaN   NaN   NaN          NaN   NaN   NaN  11-10-2002-CHI
# 20979      NaN   NaN   NaN          NaN   NaN   NaN   11-17-2002-TB
# 20980      NaN   NaN   NaN          NaN   NaN   NaN  11-24-2002-DEN
# 20981      NaN   NaN   NaN          NaN   NaN   NaN  12-01-2002-PHI
# 20982      NaN   NaN   NaN          NaN   NaN   NaN  12-08-2002-PIT
# 20983      NaN   NaN   NaN          NaN   NaN   NaN   12-15-2002-NO
# 20984      NaN   NaN   NaN          NaN   NaN   NaN  12-21-2002-ARI
# 20985      NaN   NaN   NaN          NaN   NaN   NaN   12-29-2002-NE
# 20986      NaN   NaN   NaN          NaN   NaN   NaN  09-10-2001-DEN
# 20987      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-NYJ
# 20988      NaN   NaN   NaN          NaN   NaN   NaN  11-11-2001-ATL
# 20989      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-TEN
# 20990      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-JAC
# 20991      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-PHI
# 20992      NaN   NaN   NaN          NaN   NaN   NaN   09-09-2001-SF
# 20993      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-DAL
# 20994      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-BUF
# 20995      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-MIN
# 20996      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-BAL
# 20997      NaN   NaN   NaN          NaN   NaN   NaN   09-09-2001-GB
# 20998      NaN   NaN   NaN          NaN   NaN   NaN  09-09-2001-CIN
# 20999      NaN   NaN   NaN          NaN   NaN   NaN   09-09-2001-SD
# 21000      NaN   NaN   NaN          NaN   NaN   NaN  11-26-2000-IND
# 21001      NaN   NaN   NaN          NaN   NaN   NaN   09-26-1999-KC
#
#              Date  Exp  HPen  HPenYd   LastName RefPosition  VPen  VPenYd
# 0      2011-09-11  227     1       3      Green     Referee     5      30
# 1      2011-09-11  227     1       3      Green     Referee     5      30
# 2      2011-09-11  227     1       3      Green     Referee     5      30
# 3      2011-09-11  227     1       3      Green     Referee     5      30
# 4      2011-09-11  227     1       3      Green     Referee     5      30
# 5      2011-09-11  227     1       3      Green     Referee     5      30
# 6             NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 7             NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 8             NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 9             NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 10            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 11            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 12            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 13            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 14            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 15            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 16            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 17            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 18            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 19     2011-10-02  201     3      15  Steratore     Referee     4      26
# 20     2011-10-02  201     3      15  Steratore     Referee     4      26
# 21     2011-10-02  201     3      15  Steratore     Referee     4      26
# 22     2011-10-02  201     3      15  Steratore     Referee     4      26
# 23     2011-10-02  201     3      15  Steratore     Referee     4      26
# 24            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 25            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 26            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 27            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 28            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# 29            NaN  NaN   NaN     NaN        NaN         NaN   NaN     NaN
# ...           ...  ...   ...     ...        ...         ...   ...     ...
# 20972  2002-09-16   61     7      55    McElwee     Referee     4      30
# 20973  2002-09-29   61    10     117    McElwee     Referee    11      77
# 20974  2002-10-06   61     6      45    McElwee     Referee     6      62
# 20975  2002-10-13   61     6      35    McElwee     Referee     3      20
# 20976  2002-10-20   61     4      30    McElwee     Referee     5      30
# 20977  2002-10-27   61     6      40    McElwee     Referee     7      45
# 20978  2002-11-10   61     5      30    McElwee     Referee     6      65
# 20979  2002-11-17   61     5      34    McElwee     Referee     2      10
# 20980  2002-11-24   61     9      58    McElwee     Referee     4      31
# 20981  2002-12-01   61     9      65    McElwee     Referee     5      35
# 20982  2002-12-08   61     8      57    McElwee     Referee     1      18
# 20983  2002-12-15   61     8      53    McElwee     Referee     8      73
# 20984  2002-12-21   61     1      15    McElwee     Referee     4      30
# 20985  2002-12-29   61     4      20    McElwee     Referee     6      83
# 20986  2001-09-10    2     6      36      Athan     Referee     7      35
# 20987  2001-09-09    2     3      30    Havener     Referee     2      10
# 20988  2001-11-11    2     2      10   Mitchell     Referee     4      41
# 20989  2001-09-09    1    12      77     Briggs     Referee     9     128
# 20990  2001-09-09    1     4      31     Gentry     Referee     4      29
# 20991  2001-09-09    1     2      20      Hynes     Referee     7      45
# 20992  2001-09-09    1     6      60    Johnson     Referee     3      25
# 20993  2001-09-09    1     4      32    Labenne     Referee     6      61
# 20994  2001-09-09    1     4      35     Mallam     Referee     4      35
# 20995  2001-09-09    1     7      40  McKreight     Referee     7      57
# 20996  2001-09-09    1     6      55      Rider     Referee     5      56
# 20997  2001-09-09    1     4      35   Sizemore     Referee     4      57
# 20998  2001-09-09    1     3      20      Smith     Referee     3      15
# 20999  2001-09-09    1     5      49   Sprenger     Referee     6      69
# 21000  2000-11-26    1    10      78       Blum     Referee     4      30
# 21001  1999-09-26    1     6      70      Garth     Referee     7      52
#
# [21002 rows x 20 columns]

# %%
print f.columns.values
c = f[(f['Season'] >= 2015)]
r = c[(c['RefPosition'] == 'Referee')]
r['H-VPen'] = r['HPen'] - r['VPen']
rc = r.groupby(['HTeam','Week','Year'], as_index = False).count()
print rc[['HTeam']].describe()
#rm = r.groupby(['HTeam'], as_index = False).mean()
print rc.head(10)

#plt.figure(figsize=(16, 8))
#sns.swarmplot(x = 'HTeam', y = 'Penalty', data = rc)
# Out:
# ['HTeam' 'NDate' 'VTeam' 'Team' 'Penalty' 'Opponent' 'Player' 'Position'
#  'Week' 'Year' 'PenaltyIndex' 'key' 'Date' 'Exp' 'HPen' 'HPenYd' 'LastName'
#  'RefPosition' 'VPen' 'VPenYd' 'HScore' 'HVScoreDiff' 'Season' 'VScore'
#  'Winner' 'day' 'eid' 'gamekey' 'meridiem' 'month' 'gametype' 'time' 'wday'
#  'week' 'year' 'Stadium' 'Capacity' 'City' 'State/Province' 'Surface'
#  'Opened']
#        HTeam
# count    125
# unique    30
# top      PHI
# freq       7
#   HTeam  Week  Year  NDate  VTeam  Team  Penalty  Opponent  Player  Position  \
# 0   ARI     7  2015      9      9     9        9         9       9         9
# 1   ARI    11  2015     10     10    10       10        10      10        10
# 2   ARI    14  2015      5      5     5        5         5       5         5
# 3   ARI    16  2015     10     10    10       10        10      10        10
# 4   ATL     5  2015      6      6     6        6         6       6         6
# 5   ATL    11  2015      8      8     8        8         8       8         8
# 6   ATL    12  2015     10     10    10       10        10      10        10
# 7   ATL    16  2015      6      6     6        6         6       6         6
# 8   BAL     5  2015     10     10    10       10        10      10        10
# 9   BAL    10  2015      5      5     5        5         5       5         5
#
#     ...    wday  week  year  Stadium  Capacity  City  State/Province  Surface  \
# 0   ...       9     9     9        9         9     9               9        9
# 1   ...      10    10    10       10        10    10              10       10
# 2   ...       5     5     5        5         5     5               5        5
# 3   ...      10    10    10       10        10    10              10       10
# 4   ...       6     6     6        6         6     6               6        6
# 5   ...       8     8     8        8         8     8               8        8
# 6   ...      10    10    10       10        10    10              10       10
# 7   ...       6     6     6        6         6     6               6        6
# 8   ...      10    10    10       10        10    10              10       10
# 9   ...       5     5     5        5         5     5               5        5
#
#    Opened  H-VPen
# 0       9       9
# 1      10      10
# 2       5       5
# 3      10      10
# 4       6       6
# 5       8       8
# 6      10      10
# 7       6       6
# 8      10      10
# 9       5       5
#
# [10 rows x 42 columns]
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-77cd230c941e> in <module>()
#       1 plt.figure(figsize=(16, 8))
# ----> 2 sns.swarmplot(x = 'Stadium', y = 'HPen', data = f)
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in swarmplot(x, y, hue, data, order, hue_order, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2691                        linewidth=linewidth))
#    2692
# -> 2693     plotter.plot(ax, kwargs)
#    2694     return ax
#    2695
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in plot(self, ax, kws)
#    1391     def plot(self, ax, kws):
#    1392         """Make the full plot."""
# -> 1393         self.draw_swarmplot(ax, kws)
#    1394         self.add_legend_data(ax)
#    1395         self.annotate_axes(ax)
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in draw_swarmplot(self, ax, kws)
#    1387         for center, swarm in zip(centers, swarms):
#    1388             if swarm.get_offsets().size:
# -> 1389                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1390
#    1391     def plot(self, ax, kws):
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in swarm_points(self, ax, points, center, width, s, **kws)
#    1296
#    1297         # Do the beeswarm in point coordinates
# -> 1298         new_xy = self.beeswarm(orig_xy, d)
#    1299
#    1300         # Transform the point coordinates back to data coordinates
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in beeswarm(self, orig_xy, d)
#    1256             # Remove the positions that overlap with any of the
#    1257             # other neighbors
# -> 1258             candidates = self.prune_candidates(candidates, neighbors, d)
#    1259
#    1260             # Find the most central of the remaining positions
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in prune_candidates(self, candidates, neighbors, d)
#    1228             good_candidate = True
#    1229             for xy_j in neighbors:
# -> 1230                 if self.overlap(xy_i, xy_j, d):
#    1231                     good_candidate = False
#    1232             if good_candidate:
#
# KeyboardInterrupt:

# %%
c = rfp[(rfp['Season'] == 2015)]
r = c[(c['RefPosition'] == 'Referee')]
rc = r.groupby(['LastName', 'Penalty'], as_index = False).count()
rm = r.groupby(['LastName','Penalty'], as_index = False).mean()[['LastName','Penalty','HPen','VPen','HVScoreDiff']]
rm['H-VPen'] = rm['HPen'] - rm['VPen']

#print rc
plt.figure(figsize=(16, 8))
sns.swarmplot(x = 'LastName', y = 'H-VPen', data = rm)

# %%
#THIS IS EXCELLENT EXAMPLE OF MULTI_INDEX JOINING. NO TOUCHIE!

fname = '/Users/kelly89/NFLPenalties/RefAndPenalties.csv'
f = pd.read_csv(fname, sep = ',')
#print f

gameDataF = '/Users/kelly89/NFLPenalties/AllGameData.csv'
gd = pd.read_csv(gameDataF, sep=',')
#print gd.head(5)

#a.set_index('NDate','HTeam')
#h = gd.set_index('NDate','HTeam')
f = f.set_index(['NDate','HTeam','VTeam'])
g = gd.set_index(['NDate','HTeam','VTeam'])

m = pd.merge(f, g, left_index = True, right_index = True)
n = m.reset_index()
print n.head(10)
#print o.dropna().shape
# Out:
#         NDate HTeam VTeam Team      Penalty Opponent      Player Position  \
# 0  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 1  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 2  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 3  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 4  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 5  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 6  10/10/2011   DET   CHI  CHI  False Start      DET     K.Davis       TE
# 7  10/10/2011   DET   CHI  CHI  False Start      DET  C.Williams        T
# 8  10/10/2011   DET   CHI  CHI  False Start      DET  C.Williams        T
# 9  10/10/2011   DET   CHI  CHI  False Start      DET  C.Williams        T
#
#    Week  Year  ...  day         eid gamekey  meridiem  month  gametype  time  \
# 0     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 1     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 2     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 3     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 4     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 5     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 6     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 7     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 8     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
# 9     5  2011  ...   10  2011101000   55240       NaN     10       REG  8:30
#
#    wday  week  year
# 0   Mon     5  2011
# 1   Mon     5  2011
# 2   Mon     5  2011
# 3   Mon     5  2011
# 4   Mon     5  2011
# 5   Mon     5  2011
# 6   Mon     5  2011
# 7   Mon     5  2011
# 8   Mon     5  2011
# 9   Mon     5  2011
#
# [10 rows x 34 columns]

# %%
#THIS IS EXCELLENT EXAMPLE OF MULTI_INDEX JOINING. NO TOUCHIE!

fname = '/Users/kelly89/NFLPenalties/WithPlayerStats.csv'
f = pd.read_csv(fname, sep = ',')
#print f

gameDataF = '/Users/kelly89/NFLPenalties/AllGameData.csv'
gd = pd.read_csv(gameDataF, sep=',')
#print gd.head(5)

#a.set_index('NDate','HTeam')
#h = gd.set_index('NDate','HTeam')
f = f.set_index(['NDate','HTeam','VTeam'])
g = gd.set_index(['NDate','HTeam','VTeam'])

m = pd.merge(f, g, left_index = True, right_index = True)
n = m.reset_index()
print n.head(10)
#print o.dropna().shape

r = n[(n['Season'] == 2015)]
g = r.groupby(['Player','Week']).count()
print g.Penalty.sort_values(ascending = False)
#print n.groupby(['Team','Season','wday']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-25a7f185c434> in <module>()
#      11 #a.set_index('NDate','HTeam')
#      12 #h = gd.set_index('NDate','HTeam')
# ---> 13 f = f.set_index(['NDate','HTeam','VTeam'])
#      14 g = gd.set_index(['NDate','HTeam','VTeam'])
#      15
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2778                 names.append(None)
#    2779             else:
# -> 2780                 level = frame[col]._values
#    2781                 names.append(col)
#    2782                 if drop:
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'NDate'

# %%
f = pd.read_csv('/Users/kelly89/NFLPenalties/WithPlayerStats.csv')
f.columns = a.columns.values
print f.shape

s = a[((a['HTeam'] == 'SEA') | (a['VTeam'] == 'SEA')) & (a['Year'] == 2015)]
b = a.groupby(['Penalty'], as_index = False).count()[['Penalty','Team']].sort_values('Team', ascending = False)
t10 = b.head(10).Penalty.values

j = a[(a['Penalty'].isin(t10))]
k = j.groupby(['Penalty', 'Team'], as_index = False).mean()
l = j.groupby(['Penalty', 'Team'], as_index = False).count()
print k.columns.values
print k.head(10)

m = b.head(4).Penalty.values
print m

sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

n = a[(a['Penalty'].isin(m))]
o = n.groupby(['Penalty', 'Team'], as_index = False).mean()
p = n.groupby(['Penalty', 'Team'])['Penalty'].count().unstack('Penalty').fillna(0)
p.plot(kind='bar', stacked=True)

#p1 = p[(p['Penalty'] == 'Offensive Holding')].key.iloc[0]
#p2 = p[(p['Penalty'] == 'False Start')].key.iloc[0]
#p3 = p[(p['Penalty'] == 'Defensive Pass Interference')].key.iloc[0]
#p4 = p[(p['Penalty'] == 'Defensive Holding')].key.iloc[0]


#test5 = p.groupby(['Site Name', 'Abuse/NFF'])['Site Name'].count().unstack('Abuse/NFF').fillna(0)

#g = sns.FacetGrid(attend, col="subject", col_wrap=4, size=2, ylim=(0, 10))
#g.map(sns.pointplot, "solutions", "score", color=".3", ci=None);

#g = sns.violinplot(x = 'Penalty', y = 'NumPenalty', data = l, saturation = 0.5, color = "Grey", legend = False)
#g = sns.swarmplot(x = 'Penalty', y = 'NumPenalty', hue = 'LastName', data = l)
#plt.legend = False

# %%
rp = pd.read_csv(ofile, sep=',')
rp['H-V'] = rp['HPen'] - rp['VPen']
rp['H-VYd'] = rp['HPenYd'] - rp['VPenYd']

cPen = rp.groupby('Penalty', as_index = False).count()
commonPens = cPen.sort_values('key', ascending = False).Penalty.head(8)
a = rp[rp['Penalty'].isin(commonPens)]

e = a[(a['Exp'] > 200)]
gByRef = e.groupby(['LastName','Penalty'], as_index = False).mean()
gByRef['NormH-VYd'] = gByRef['H-VYd'] / gByRef['Exp']


sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

#print gByRef[['LastName','Penalty','NormH-VYd']].sort_values('NormH-VYd', ascending = False)
g = sns.boxplot(x = 'Penalty', y = 'H-VYd', data = gByRef, saturation = 0.1, color = "Black")
g = sns.swarmplot(x = 'Penalty', y = 'H-VYd', data = gByRef)
#sns.violinplot(x = 'Penalty', y = 'H-VYd', data = gByRef)
#sns.stripplot(x = 'Penalty', y = 'H-VYd', data = gByRef)

g.axes.set_title('Average Home-Field Advantage By Penalty', fontsize=34,color="Black")

# %%
print a[['NDate']]
# Out:
#              NDate
# 0       09/11/2011
# 1       09/11/2011
# 2       09/11/2011
# 3       09/11/2011
# 4       09/11/2011
# 5       09/11/2011
# 6       09/11/2011
# 7       09/11/2011
# 8       09/11/2011
# 9       09/11/2011
# 10      09/11/2011
# 11      09/11/2011
# 12      09/11/2011
# 13      09/11/2011
# 14      09/11/2011
# 15      09/11/2011
# 16      09/11/2011
# 17      09/11/2011
# 18      09/11/2011
# 19      09/11/2011
# 20      09/11/2011
# 21      09/11/2011
# 22      09/11/2011
# 23      09/11/2011
# 24      09/11/2011
# 25      09/11/2011
# 26      09/11/2011
# 27      09/11/2011
# 28      11/10/2013
# 29      11/10/2013
# ...            ...
# 104966  09/20/2015
# 104967  09/20/2015
# 104968  09/20/2015
# 104969  09/20/2015
# 104970  09/20/2015
# 104971  09/20/2015
# 104972  09/20/2015
# 104973  09/20/2015
# 104974  09/20/2015
# 104975  11/08/2015
# 104976  11/08/2015
# 104977  11/08/2015
# 104978  11/08/2015
# 104979  11/08/2015
# 104980  11/08/2015
# 104981  11/08/2015
# 104982  11/29/2015
# 104983  11/29/2015
# 104984  11/29/2015
# 104985  11/29/2015
# 104986  11/29/2015
# 104987  11/29/2015
# 104988  11/29/2015
# 104989  11/29/2015
# 104990  11/29/2015
# 104991  11/29/2015
# 104992  11/29/2015
# 104993  11/29/2015
# 104994  11/29/2015
# 104995  11/29/2015
#
# [104996 rows x 1 columns]

# %%
#def GetGameStats(row):
#    wk = row.
#print data
#g = nflgame.one(2011, 17, "NE", "BUF")
#print data.columns.values
#print data.head(5)
print e[(e['key'] == '09-11-2011-KC')]
#m = data.groupby(['team','game'], as_index = False).mean()
#print m.head(5)
print data[(data['game'] == '09/11/2011') & (data['player'] == 'J.Houston')]
print rp.columns.values
print rp[(rp['NDate'] == '09/11/2011') & (rp['Player'] == 'J.Houston')]

# %%
  


#Could 
def GetPlayersByGame(g)
    hp = g.players.filter(home = True)
    ap = g.players.filter(home = False)

print data.head(4)
#rd['key'] = rd.apply(MakeKey, axis=1)


def MatchRefToPenalty(b):
    #print b
    date = b.Date.split('/')
    print date
    d = str(date[2] + '-' + date[0] + '-' + date[1])
    print d
    m = rd.loc[(rd['Date'] == '2011-09-11')]
    print m['LastName','HTeam']



print rp.columns.values
rp['Exp'] = map(int, rp['Exp'])
e = rp[(rp['key'] > 200)]
e = e[(e['Position_x'] == 'Umpire')]
c = e.groupby('Penalty', as_index = False).count()
d = c[(c['key'] > 200)]
CommonPens = d.Penalty.unique()

p = e[e['Penalty'].isin(CommonPens)]
print p.shape

# %%
def FindGame(t):
    g = nflgame.one(i.Year[0], i.Week[0], i.Team[0], i.Team[0])
    
    homeTm =  g.home
    visTm = g.away
    
    print homeTm
    print visTm

    #g = nflgame.one(2011, 17, 'ARI', 'ARI')
    #print g
    
r = data[(data['Week'] <= 17)]
r = r.groupby(['Team','NDate','Week','Year'], as_index = False).count()
s = r.head(5)
#s['GameObj'] = s.apply(lambda x: nflgame.one(x['Year'], x['Week'], str(x['Team']), str(x['Team'])), axis = 1)
s['Season'] = s.apply(lambda x: nflgame.one(x['Year'], x['Week'], str(x['Team']), str(x['Team'])).season(), axis = 1)
s['HomeTeam'] = s.apply(lambda x: nflgame.one(x['Year'], x['Week'], str(x['Team']), str(x['Team'])).home, axis = 1)
s['VisTeam'] = s.apply(lambda x: nflgame.one(x['Year'], x['Week'], str(x['Team']), str(x['Team'])).away, axis = 1)
s['WinTeam'] = s.apply(lambda x: nflgame.one(x['Year'], x['Week'], str(x['Team']), str(x['Team'])).winner, axis = 1)
print s

# %%
#Get game data

def GetGameData(year):
    games = nflgame.games_gen(year, 1)
    a = pd.DataFrame() 
    for g in games:
        Schedule = g.schedule
        s = pd.DataFrame.from_dict([Schedule])
        extra = {'HScore': g.score_home, 'VScore': g.score_away, 'Winner': g.winner, 'Season': g.season()}
        e = pd.DataFrame.from_dict([extra])
        r = s.join(e)
        r['HVScoreDiff'] = r['HScore'] - r['VScore']
        a = pd.concat([a, r])
    print a
    return a

def GetAllGameData(fname):
    allyears = pd.DataFrame()
    for year in range(2015,2016):
        yr = GetGameData(year)
        allyears = pd.concat([allyears, yr])
    print allyears
    
fname = '/Users/kelly89/NFLPenalties/AllGameData.csv'
GetAllGameData(fname)

# %%
gameDataF = '/Users/kelly89/NFLPenalties/AllGameData.csv'
gd = pd.read_csv(gameDataF, sep=',')
#print gd.head(5)

f = pd.read_csv('/Users/kelly89/NFLPenalties/WithPlayerStats.csv')
f.columns = a.columns.values 
print f.shape

#a.set_index('NDate','HTeam')
h = gd.set_index('NDate','HTeam')
ai = a.set_index('NDate','Team')

o = pd.concat([h, ai])
print o.shape

print o.dropna().shape
# Out:
# (104995, 25)
# (106788, 39)
# (0, 39)

# %%
print a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d7b17ad5387> in <module>()
# ----> 1 print a
#
# NameError: name 'a' is not defined

# %%
fname = '/Users/kelly89/NFLPenalties/WithPlayerStats.csv'
pstats = pd.read_csv('PlayerStats.csv', sep = ',')
pstats.columns = ['Player','Height','Weight','College','Birthdate','YearsProRT2015','Team']
pstats = pstats.drop(['Team','YearsProRT2015'], axis=1)
t = pd.merge(rp, pstats, left_on='Player', right_on='Player', how = 'right')
t = t.drop('PenaltyIndex', axis = 1)
#print t.shape
t = t.dropna()
t.reindex()

a = t.loc[0:,]
#b = a.groupby(['Team','HTeam','VTeam','Date'], as_index = False).count()
#c = a.groupby(['Team','HTeam','VTeam','Date'], as_index = False).mean()
a['IsHomeTeam'] = np.where((a['Team'] == a['HTeam']), True, False)
a['NumPenalty'] = np.where((a['Team'] == a['HTeam']), a['HPen'], a['VPen'])
a['PenaltyYds'] = np.where((a['Team'] == a['HTeam']), a['HPenYd'], a['VPenYd'])

#Test
#print c[(c['VTeam'] == 'WAS')].head(5)
#print c[(c['HTeam'] == 'WAS')].head(5)
header = a.columns.values
print a
np.savetxt(fname, a, fmt = '%s',delimiter=',')
