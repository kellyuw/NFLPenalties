# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np
import nflgame
import os
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

#Setting for displaying inline graphics with matplotlib
# %matplotlib inline

# %%
#Custom color palettes for graphs
custompal = ["#F44336","#E91E63","#9C27B0","#673AB7","#3F51B5","#2196F3","#03A9F4","#00BCD4","#009688","#4CAF50",
             "#8BC34A","#CDDC39","#FFEB3B","#FFC107","#FF9800","#FF5722","#795548","#9E9E9E","#607D8B"]
minicustom = custompal[::2]
sns.set_palette(minicustom)
#sns.palplot(custompal)

sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))
teams = ['buffalo-bills', 'miami-dolphins', 'new-england-patriots', 'new-york-jets', 'baltimore-ravens',
         'cincinnati-bengals', 'cleveland-browns', 'pittsburgh-steelers', 'houston-texans', 'indianapolis-colts',
         'jacksonville-jaguars', 'tennessee-titans', 'denver-broncos', 'kansas-city-chiefs', 'oakland-raiders',
         'san-diego-chargers', 'dallas-cowboys', 'new-york-giants', 'philadelphia-eagles', 'washington-redskins',
         'chicago-bears', 'detroit-lions', 'green-bay-packers', 'minnesota-vikings', 'atlanta-falcons',
         'carolina-panthers', 'new-orleans-saints', 'tampa-bay-buccaneers', 'arizona-cardinals',
         'san-francisco-49ers', 'seattle-seahawks', 'st-louis-rams']

def GetStdTeam(team):
    #Convert team name into easily parsable string
    tm = team.replace('-',' ')

    #Rams no longer in St. Louis (so just use Rams for search)
    if ("rams" in tm):
        tm = "rams"

    #Get standard team name
    stdteam = nflgame.standard_team(str(tm))
    return stdteam


def GetPenaltyData(team, year):
    print 'Getting data for ' + team + ' ' + year

    #Set up url string
    teamfile = 'http://www.nflpenalties.com/team/' + team + '?year=' + year + '&view=log'

    #Set up BeautifulSoup parser
    r = urllib.urlopen(teamfile).read()
    soup = BeautifulSoup(r, "lxml")
    print type(soup)

    #Get content
    content = soup.find_all("div", id="content")

    return content


def ParseContent(content, stdteam):
    tb = content[0].find('tbody')
    y = pd.DataFrame()
    z = ['team','penalty','game','opponent','player','position','week','year','penaltyindex']
    count = 0
    missing = 0

    for row in tb.findAll('tr'):
        missing = str(row).count('></a>')

        if (missing == 0):
            for link in row.findAll('a'):

                href = link['href']
                linkinfo = href.split('/')
                linkcat = str(linkinfo[1])

                linkdetails = str(link.get_text())

                if (linkcat == 'penalty'):
                    t = [stdteam]

                if ('week.php' not in href):
                    t = np.hstack([t, linkdetails])
                else:
                    weekandyear = href.split('week=')[1]
                    week = weekandyear.split('?')[0]
                    year = weekandyear.split('year=')[1]

                    t = np.hstack([t, week, year])

                    penaltyindex = stdteam + '-' + str(year) + '-' + str(count)

                    t = np.hstack([t, penaltyindex])
                    z = np.vstack([z,t])
                    count += 1
        else:
            missing += 1

    totalpenalties = missing + count
    z['opponent'] = z['opponent'].apply(lambda x: GetStdTeam(x))
    return [z,totalpenalties]

#This writes CSV of data for particular team and year
def WritePenaltyData(penalties, stdteam, year, fname):
    totalnumpenalties = penalties[1]
    print stdteam + ',' + year + ',' + str(totalnumpenalties)
    np.savetxt(fname, penalties[0], fmt = '%s', delimiter=',')

#Gets data from all teams into dataframe for particular year
def GetAllTeams(year):
    data = pd.DataFrame()
    for team in teams:
        stdteam = GetStdTeam(team)
        print stdteam
        fname = '/Users/kelly89/NFLPenalties/' + stdteam + year + '.csv'

        if (os.path.isfile(fname) == False):
            content = GetPenaltyData(team, year)
            penalties = ParseContent(content, stdteam)
            WritePenaltyData(penalties, stdteam, year, fname)
        else:
            print 'Found data file for ' + stdteam + ' ' + year

        temp = pd.read_csv(fname, sep = ',')
        data = pd.concat([data,temp], ignore_index = True)
    return data

#Writes main CSV (penalty data fro all teams and all years from 2011-2015)
def GetAllYears(fname):
    alldata = pd.DataFrame()
    for year in ['2011','2012','2013','2014','2015']:
        tempyear = GetAllTeams(year)
        alldata = pd.concat([alldata,tempyear], ignore_index = True)

    alldata.columns = ['Team','Penalty','NDate','Opponent','Player','Position','Week','Year','PenaltyIndex']
    alldata['Opponent'] = alldata['Opponent'].apply(lambda x: GetStdTeam(x))
    d = alldata.dropna()
    d.to_csv(fname, sep = ',')

def GetRegSeasonRecord (team, year):
    team = str(team)
    year = int(year)

    games = nflgame.games_gen(year, week = None, home = team, away = team, kind = 'REG')
    for g in games:
        print g
        if (g.winner == team):
            w += 1
        elif (g.loser == team):
            l += 1
        else:
            print "ERROR: can not determine winner of this game"

        print 'W-L: ' + str(w) + '-' + str(l)

    return [int(w),int(l)]

def GetAllRefInfo(fname):
    pfr = 'http://www.pro-football-reference.com/officials'
    pfrUrl = urllib.urlopen(pfr).read()
    pfrSoup = BeautifulSoup(pfrUrl, "lxml")
    content = pfrSoup.find_all("div", id="page_content")

    a = content[0].find('table')
    b = pd.DataFrame()
    c = ['webpage','name','games','positions','years']
    count = 0
    m = 0
    e = []

    for row in a.findAll('tr')[1:]:
        m = str(row).count('></td>')
        webpage = os.path.dirname(pfr) + str(row.findNext('a')['href'])
        e = [webpage]
        for val in row.findAll('td'):
            d = val.get_text()
            e = np.hstack([e, str(d)])
        if (len(e) == 5):
            c = np.vstack([c,e])
            count += 1
        else:
            m += 1
    GetAllRefGames(c[1:], fname)

def GetAllRefGames(refinfo, fname):
    refstats = ['ref','exp','date','visitor','home','position','vpen','vpenyd','hpen','hpenyd']

    for ref in refinfo:
        refname = ref[1].rpartition(' ')[2]
        exp = str(ref[2])
        print 'Getting data for ' + refname

        refUrl = urllib.urlopen(ref[0]).read()
        refSoup = BeautifulSoup(refUrl, "lxml")

        i = refSoup.find_all("div", id="div_game_logs")[0]

        for row in i.findAll('tr'):
            j = []
            alltd = row.findAll("td")
            if (len(alltd) != 0):
                date = alltd[0].get_text()
                teams = alltd[1].get_text().split(' @ ')
                v = nflgame.standard_team(teams[0].rpartition(' ')[2])
                h = nflgame.standard_team(teams[1].rpartition(' ')[2])
                pos = alltd[2].get_text().replace(' ','-')
                vpen = alltd[4].get_text()
                vpenyd = alltd[5].get_text()
                hpen = alltd[7].get_text()
                hpenyd = alltd[8].get_text()

                j = np.hstack([refname, exp, date, v, h, pos, vpen, vpenyd, hpen, hpenyd])

                if (len(j) == 10):
                    refstats = np.vstack([refstats, j])
            print refstats
            


def NormDate(date):
    d = date.split('-')
    d = str(d[1] + '/' + d[2] + '/' + d[0])
    return str(d)

def MakeKey(r):
    yr = r.NDate.replace('/','-')
    k = str(yr + '-' + r.HTeam)
    return k

def GetHomeTm(r, homeTms):
    if (r.Team in homeTms):
        return r.Team
    else:
        return r.Opponent


def GetAwayTm(r, homeTms):
    if (r.Team not in homeTms):
        return r.Team
    else:
        return r.Opponent

def MergePenaltyAndRefs(fname, data, rd):

    rd['NDate'] = rd['Date'].apply(lambda x: NormDate(x))
    rd['Year'] = rd['NDate'].apply(lambda x: str(x).split('/')[2])

    penYears = map(str, range(2011,2016))
    rd = rd.loc[rd['Year'].isin(penYears)]

    #Add column to determine if player was on home team
    a = rd.groupby(['HTeam', 'NDate'], as_index = False).count()
    data['HTeam'] = data.apply(lambda x: GetHomeTm(x, a[(a['NDate'] == str(x.NDate))]), axis=1)
    data['VTeam'] = data.apply(lambda x: GetAwayTm(x, a[(a['NDate'] == str(x.NDate))]), axis=1)

    rd['key'] = rd.apply(MakeKey, axis=1)
    data['key'] = data.apply(MakeKey, axis=1)

    uniqcols = rd.columns.difference(data.columns)
    newrd = pd.concat([rd[['key']],rd[uniqcols]], axis=1)
    c = pd.merge(data, newrd, left_on='key', right_on='key')
    c.to_csv(fname, sep=",")



#Main code

#Get penalty data for all years into dataframe
allPenF = '/Users/kelly89/NFLPenalties/AllPenalties.csv'
if (os.path.isfile(allPenF) == False):
    GetAllYears(allPenF)
else:
    print 'Found ' + allPenF
data = pd.read_csv(allPenF, sep=",")
print data.shape

#Get refdata into dataframe
refDataF = '/Users/kelly89/NFLPenalties/RefData.csv'
if (os.path.isfile(refDataF) == False):
    GetAllRefInfo(refDataF)
else:
    print 'Found ' + refDataF
rd = pd.read_csv(refDataF, sep=",")
print rd.shape

#Merge ref data with penalty data
refPenF = '/Users/kelly89/NFLPenalties/RefAndPenalties.csv'
if (os.path.isfile(refPenF) == False):
    MergePenaltyAndRefs(refPenF, data, rd)
else:
    print 'Found ' + refPenF
rp = pd.read_csv(refPenF, sep=',')
print rp.shape



#Merge demographics with penalty info.
#pstats = pd.read_csv('PlayerStats.csv', sep = ',')
#pstats.columns = ['player','height','weight','college','birthdate','yearspro','team']
#result = pd.merge(data, pstats, how='left', on=['player'])

#Get RefInfo
#GetAllRefInfo()
# Out:
# Found /Users/kelly89/NFLPenalties/AllPenalties.csv
# (17682, 9)
# Found /Users/kelly89/NFLPenalties/RefData.csv
# (31538, 10)
# Found /Users/kelly89/NFLPenalties/RefAndPenalties.csv
# (61009, 19)

# %%
fname = '/Users/kelly89/NFLPenalties/WithPlayerStats.csv'
pstats = pd.read_csv('PlayerStats.csv', sep = ',')
pstats.columns = ['Player','Height','Weight','College','Birthdate','YearsProRT2015','Team']
pstats = pstats.drop(['Team','YearsProRT2015'], axis=1)
t = pd.merge(rp, pstats, left_on='Player', right_on='Player', how = 'right')
t = t.drop('PenaltyIndex', axis = 1)
#print t.shape
t = t.dropna()
t.reindex()

a = t.loc[0:,]
#b = a.groupby(['Team','HTeam','VTeam','Date'], as_index = False).count()
#c = a.groupby(['Team','HTeam','VTeam','Date'], as_index = False).mean()
a['IsHomeTeam'] = np.where((a['Team'] == a['HTeam']), True, False)
a['NumPenalty'] = np.where((a['Team'] == a['HTeam']), a['HPen'], a['VPen'])
a['PenaltyYds'] = np.where((a['Team'] == a['HTeam']), a['HPenYd'], a['VPenYd'])

#Test
#print c[(c['VTeam'] == 'WAS')].head(5)
#print c[(c['HTeam'] == 'WAS')].head(5)
header = a.columns.values
print a
np.savetxt(fname, a, fmt = '%s',delimiter=',')
# Out:
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/kelly89/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Team                  Penalty       NDate Opponent        Player  \
# 0       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 1       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 2       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 3       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 4       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 5       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 6       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 7       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 8       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 9       BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 10      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 11      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 12      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 13      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 14      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 15      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 16      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 17      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 18      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 19      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 20      BUF     Face Mask (15 Yards)  09/11/2011       KC       J.White
# 21      BUF              False Start  09/11/2011       KC       E.Pears
# 22      BUF              False Start  09/11/2011       KC       E.Pears
# 23      BUF              False Start  09/11/2011       KC       E.Pears
# 24      BUF              False Start  09/11/2011       KC       E.Pears
# 25      BUF              False Start  09/11/2011       KC       E.Pears
# 26      BUF              False Start  09/11/2011       KC       E.Pears
# 27      BUF              False Start  09/11/2011       KC       E.Pears
# 28      BUF     Illegal Use of Hands  11/10/2013      PIT       E.Pears
# 29      BUF     Illegal Use of Hands  11/10/2013      PIT       E.Pears
# ...     ...                      ...         ...      ...           ...
# 104966  STL     Illegal Substitution  09/20/2015      WAS  B.Cunningham
# 104967  STL     Illegal Substitution  09/20/2015      WAS  B.Cunningham
# 104968  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104969  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104970  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104971  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104972  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104973  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104974  STL  Neutral Zone Infraction  09/20/2015      WAS  E.Westbrooks
# 104975  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104976  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104977  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104978  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104979  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104980  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104981  STL        Offensive Holding  11/08/2015      MIN    J.McQuaide
# 104982  STL              False Start  11/29/2015      CIN      C.Bryant
# 104983  STL              False Start  11/29/2015      CIN      C.Bryant
# 104984  STL              False Start  11/29/2015      CIN      C.Bryant
# 104985  STL              False Start  11/29/2015      CIN      C.Bryant
# 104986  STL              False Start  11/29/2015      CIN      C.Bryant
# 104987  STL              False Start  11/29/2015      CIN      C.Bryant
# 104988  STL              False Start  11/29/2015      CIN      C.Bryant
# 104989  STL              False Start  11/29/2015      CIN      C.Bryant
# 104990  STL              False Start  11/29/2015      CIN      C.Bryant
# 104991  STL              False Start  11/29/2015      CIN      C.Bryant
# 104992  STL              False Start  11/29/2015      CIN      C.Bryant
# 104993  STL              False Start  11/29/2015      CIN      C.Bryant
# 104994  STL              False Start  11/29/2015      CIN      C.Bryant
# 104995  STL              False Start  11/29/2015      CIN      C.Bryant
#
#        Position  Week  Year HTeam VTeam     ...           LastName VPen  \
# 0            RB     1  2011    KC   BUF     ...          Helverson    5
# 1            RB     1  2011    KC   BUF     ...          Stritesky    5
# 2            RB     1  2011    KC   BUF     ...           Prioleau    5
# 3            RB     1  2011    KC   BUF     ...            Stabile    5
# 4            RB     1  2011    KC   BUF     ...               Rose    5
# 5            RB     1  2011    KC   BUF     ...              Green    5
# 6            RB     1  2011    KC   BUF     ...             Barnes    5
# 7            RB     1  2011    KC   BUF     ...          Helverson    5
# 8            RB     1  2011    KC   BUF     ...          Stritesky    5
# 9            RB     1  2011    KC   BUF     ...           Prioleau    5
# 10           RB     1  2011    KC   BUF     ...            Stabile    5
# 11           RB     1  2011    KC   BUF     ...               Rose    5
# 12           RB     1  2011    KC   BUF     ...              Green    5
# 13           RB     1  2011    KC   BUF     ...             Barnes    5
# 14           RB     1  2011    KC   BUF     ...          Helverson    5
# 15           RB     1  2011    KC   BUF     ...          Stritesky    5
# 16           RB     1  2011    KC   BUF     ...           Prioleau    5
# 17           RB     1  2011    KC   BUF     ...            Stabile    5
# 18           RB     1  2011    KC   BUF     ...               Rose    5
# 19           RB     1  2011    KC   BUF     ...              Green    5
# 20           RB     1  2011    KC   BUF     ...             Barnes    5
# 21            T     1  2011    KC   BUF     ...          Helverson    5
# 22            T     1  2011    KC   BUF     ...          Stritesky    5
# 23            T     1  2011    KC   BUF     ...           Prioleau    5
# 24            T     1  2011    KC   BUF     ...            Stabile    5
# 25            T     1  2011    KC   BUF     ...               Rose    5
# 26            T     1  2011    KC   BUF     ...              Green    5
# 27            T     1  2011    KC   BUF     ...             Barnes    5
# 28            T    10  2013   PIT   BUF     ...              Cheek    4
# 29            T    10  2013   PIT   BUF     ...            Spanier    4
# ...         ...   ...   ...   ...   ...     ...                ...  ...
# 104966       RB     2  2015   WAS   STL     ...             Turner    9
# 104967       RB     2  2015   WAS   STL     ...             Martin    9
# 104968       DT     2  2015   WAS   STL     ...            Hochuli    9
# 104969       DT     2  2015   WAS   STL     ...              Meyer    9
# 104970       DT     2  2015   WAS   STL     ...          Helverson    9
# 104971       DT     2  2015   WAS   STL     ...             Baynes    9
# 104972       DT     2  2015   WAS   STL     ...               Hill    9
# 104973       DT     2  2015   WAS   STL     ...             Turner    9
# 104974       DT     2  2015   WAS   STL     ...             Martin    9
# 104975       LS     9  2015   MIN   STL     ...            Edwards   12
# 104976       LS     9  2015   MIN   STL     ...      Steinkerchner   12
# 104977       LS     9  2015   MIN   STL     ...          Paganelli   12
# 104978       LS     9  2015   MIN   STL     ...              Howey   12
# 104979       LS     9  2015   MIN   STL     ...            Torbert   12
# 104980       LS     9  2015   MIN   STL     ...              Yette   12
# 104981       LS     9  2015   MIN   STL     ...              Santi   12
# 104982       DB    12  2015   CIN   STL     ...            Hittner    7
# 104983       DB    12  2015   CIN   STL     ...             Zimmer    7
# 104984       DB    12  2015   CIN   STL     ...           Wrolstad    7
# 104985       DB    12  2015   CIN   STL     ...               Dyer    7
# 104986       DB    12  2015   CIN   STL     ...            Ellison    7
# 104987       DB    12  2015   CIN   STL     ...            Coleman    7
# 104987      45      76     300            Northwestern    1/4/1988
# 104988      45      76     300            Northwestern    1/4/1988
# 104989      45      80     320                 Memphis   9/11/1987
# 104990      45      80     320                 Memphis   9/11/1987
# 104991      45      80     320                 Memphis   9/11/1987
# 104992      45      80     320                 Memphis   9/11/1987
# 104993      45      80     320                 Memphis   9/11/1987
# 104994      45      80     320                 Memphis   9/11/1987
# 104995      45      80     320                 Memphis   9/11/1987
#
#         IsHomeTeam  NumPenalty  PenaltyYds
# 0            False           5          30
# 1            False           5          30
# 2            False           5          30
# 3            False           5          30
# 4            False           5          30
# 5            False           5          30
# 6            False           5          30
# 7            False           5          30
# 8            False           5          30
# 9            False           5          30
# 10           False           5          30
# 11           False           5          30
# 12           False           5          30
# 13           False           5          30
# 14           False           5          30
# 15           False           5          30
# 16           False           5          30
# 17           False           5          30
# 18           False           5          30
# 19           False           5          30
# 20           False           5          30
# 21           False           5          30
# 22           False           5          30
# 23           False           5          30
# 24           False           5          30
# 25           False           5          30
# 26           False           5          30
# 27           False           5          30
# 28           False           4          30
# 29           False           4          30
# ...            ...         ...         ...
# 104966       False           9          80
# 104967       False           9          80
# 104968       False           9          80
# 104969       False           9          80
# 104970       False           9          80
# 104971       False           9          80
# 104972       False           9          80
# 104973       False           9          80
# 104974       False           9          80
# 104975       False          12          87
# 104976       False          12          87
# 104977       False          12          87
# 104978       False          12          87
# 104979       False          12          87
# 104980       False          12          87
# 104981       False          12          87
# 104982       False           7          45
# 104983       False           7          45
# 104984       False           7          45
# 104985       False           7          45
# 104986       False           7          45
# 104987       False           7          45
# 104988       False           7          45
# 104989       False           7          45
# 104990       False           7          45
# 104991       False           7          45
# 104992       False           7          45
# 104993       False           7          45
# 104994       False           7          45
# 104995       False           7          45
#
# [104996 rows x 25 columns]

# %%
#f = pd.read_csv('/Users/kelly89/NFLPenalties/WithPlayerStats.csv')
#f.columns = c.columns.values
#print f.shape

s = a[((a['HTeam'] == 'SEA') | (a['VTeam'] == 'SEA')) & (a['Year'] == 2015)]
b = a.groupby(['Penalty'], as_index = False).count()[['Penalty','Team']].sort_values('Team', ascending = False)
t10 = b.head(10).Penalty.values

j = a[(a['Penalty'].isin(t10))]
k = j.groupby(['Penalty', 'Team'], as_index = False).mean()
l = j.groupby(['Penalty', 'Team'], as_index = False).count()
print k.columns.values
print k.head(10)

sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

g = sns.violinplot(x = 'Penalty', y = 'NumPenalty', data = l, saturation = 0.5, color = "Grey", legend = False)
g = sns.swarmplot(x = 'Penalty', y = 'NumPenalty', hue = 'LastName', data = l)
plt.legend = False

#print s.groupby(['Year']).mean()
#t = f.groupby

#values_per_group = [col for col_name, col in df.groupby(1)[2]]
#ss.ranksums(*values_per_group)

# %%
m = b.head(10).Penalty.values
print m

sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

n = a[(a['Penalty'].isin(m))]
o = n.groupby(['Penalty', 'Team'], as_index = False).mean()
p = n.groupby(['Penalty', 'Team'])['Penalty'].count().unstack('Penalty').fillna(0)
p.plot(kind='bar', stacked=True)

#p1 = p[(p['Penalty'] == 'Offensive Holding')].key.iloc[0]
#p2 = p[(p['Penalty'] == 'False Start')].key.iloc[0]
#p3 = p[(p['Penalty'] == 'Defensive Pass Interference')].key.iloc[0]
#p4 = p[(p['Penalty'] == 'Defensive Holding')].key.iloc[0]


#test5 = p.groupby(['Site Name', 'Abuse/NFF'])['Site Name'].count().unstack('Abuse/NFF').fillna(0)

#g = sns.FacetGrid(attend, col="subject", col_wrap=4, size=2, ylim=(0, 10))
#g.map(sns.pointplot, "solutions", "score", color=".3", ci=None);
# Out:
# ['Offensive Holding' 'False Start' 'Defensive Pass Interference'
#  'Defensive Holding' 'Unnecessary Roughness' 'Defensive Offside'
#  'Neutral Zone Infraction' 'Delay of Game' 'Illegal Use of Hands'
#  'Offensive Pass Interference']
# Penalty  Defensive Holding  Defensive Offside  Defensive Pass Interference  \
# Team
# ARI                    105                329                          161
# ATL                    154                 70                           98
# BAL                    294                147                          455
# BUF                    252                 35                          231
# CAR                    182                406                          266
#
# Penalty  Delay of Game  False Start  Illegal Use of Hands  \
# Team
# ARI                 91          364                    63
# ATL                 28          448                    49
# BAL                 42          448                   147
# BUF                 91          378                    56
# CAR                154          329                   238
#
# Penalty  Neutral Zone Infraction  Offensive Holding  \
# Team
# ARI                           84                336
# ATL                           42                511
# BAL                          196                511
# BUF                          224                483
# CAR                          287                595
#
# Penalty  Offensive Pass Interference  Unnecessary Roughness
# Team
# ARI                              154                    294
# ATL                              196                    238
# BAL                              343                    441
# BUF                               98                    154
# CAR                              168                    147

# %%
sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

#m = b.head(10).Penalty.values
#n = a[(a['Penalty'].isin(m))]
p = a.groupby(['Player','Year'], as_index = False).count().sort_values('Penalty', ascending = False)
print a[(a['Player'] == 'A.Adams')]
print p

#i = a.groupby(['Penalty','Player'])['Player'].count()[['Penalty','NumPenalty']]
#print i

#o = n.groupby(['Penalty', 'Team'], as_index = False).mean()
#print a.College.head(5)
#p = b.groupby(['Penalty', 'College'])['College'].count().unstack('C').fillna(0)
#p.plot(kind='bar', stacked=True)
# Out:
#       Team                Penalty       NDate Opponent   Player Position  \
# 48115  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48116  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48117  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48118  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48119  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48120  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48121  CHI           Encroachment  10/10/2011      DET  A.Adams       DT
# 48122  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48123  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48124  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48125  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48126  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48127  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
# 48128  CHI  Unnecessary Roughness  10/23/2011       TB  A.Adams       DT
#
#        Week  Year HTeam VTeam     ...       LastName VPen  VPenYd  Height  \
# 48115     5  2011   DET   CHI     ...         Horton   14     104      72
# 48116     5  2011   DET   CHI     ...         Veteri   14     104      72
# 48117     5  2011   DET   CHI     ...          Meyer   14     104      72
# 48118     5  2011   DET   CHI     ...         Seeman   14     104      72
# 48119     5  2011   DET   CHI     ...          Miles   14     104      72
# 48120     5  2011   DET   CHI     ...       Blakeman   14     104      72
# 48121     5  2011   DET   CHI     ...       DeFelice   14     104      72
# 48122     7  2011    TB   CHI     ...       Corrente    7      54      72
# 48123     7  2011    TB   CHI     ...        McGrath    7      54      72
# 2154    315     ...           315   315     315     315     315      315
# 1933    315     ...           315   315     315     315     315      315
# 1931    315     ...           315   315     315     315     315      315
# ...     ...     ...           ...   ...     ...     ...     ...      ...
# 2846      7     ...             7     7       7       7       7        7
# 2845      7     ...             7     7       7       7       7        7
# 2867      7     ...             7     7       7       7       7        7
# 1055      7     ...             7     7       7       7       7        7
# 2870      7     ...             7     7       7       7       7        7
# 2871      7     ...             7     7       7       7       7        7
# 2891      7     ...             7     7       7       7       7        7
# 2890      7     ...             7     7       7       7       7        7
# 2889      7     ...             7     7       7       7       7        7
# 2888      7     ...             7     7       7       7       7        7
# 1040      7     ...             7     7       7       7       7        7
# 2886      7     ...             7     7       7       7       7        7
# 1042      7     ...             7     7       7       7       7        7
# 1044      7     ...             7     7       7       7       7        7
# 2883      7     ...             7     7       7       7       7        7
# 1046      7     ...             7     7       7       7       7        7
# 2881      7     ...             7     7       7       7       7        7
# 2880      7     ...             7     7       7       7       7        7
# 2879      7     ...             7     7       7       7       7        7
# 2878      7     ...             7     7       7       7       7        7
# 1047      7     ...             7     7       7       7       7        7
# 2876      7     ...             7     7       7       7       7        7
# 1048      7     ...             7     7       7       7       7        7
# 1049      7     ...             7     7       7       7       7        7
# 1050      7     ...             7     7       7       7       7        7
# 1688      7     ...             7     7       7       7       7        7
# 2973      7     ...             7     7       7       7       7        7
# 2257      6     ...             6     6       6       6       6        6
# 3310      6     ...             6     6       6       6       6        6
# 1827      6     ...             6     6       6       6       6        6
#
#       Birthdate  IsHomeTeam  NumPenalty  PenaltyYds
# 241        1463        1463        1463        1463
# 245        1397        1397        1397        1397
# 242        1001        1001        1001        1001
# 737         924         924         924         924
# 736         847         847         847         847
# 3844        700         700         700         700
# 2153        693         693         693         693
# 243         693         693         693         693
# 2151        567         567         567         567
# 3843        560         560         560         560
# 2152        504         504         504         504
# 1934        504         504         504         504
# 244         462         462         462         462
# 3812        448         448         448         448
# 3728        420         420         420         420
# 3727        420         420         420         420
# 609         420         420         420         420
# 3729        420         420         420         420
# 1325        420         420         420         420
# 3842        420         420         420         420
# 1296        392         392         392         392
# 923         378         378         378         378
# 1138        364         364         364         364
# 607         350         350         350         350
# 3567        336         336         336         336
# 3568        336         336         336         336
# 85          336         336         336         336
# 2154        315         315         315         315
# 1933        315         315         315         315
# 1931        315         315         315         315
# ...         ...         ...         ...         ...
# 2846          7           7           7           7
# 2845          7           7           7           7
# 2867          7           7           7           7
# 1055          7           7           7           7
# 2870          7           7           7           7
# 2871          7           7           7           7
# 2891          7           7           7           7
# 2890          7           7           7           7
# 2889          7           7           7           7
# 2888          7           7           7           7
# 1040          7           7           7           7
# 2886          7           7           7           7
# 1042          7           7           7           7
# 1044          7           7           7           7
# 2883          7           7           7           7
# 1046          7           7           7           7
# 2881          7           7           7           7
# 2880          7           7           7           7
# 2879          7           7           7           7
# 2878          7           7           7           7
# 1047          7           7           7           7
# 2876          7           7           7           7
# 1048          7           7           7           7
# 1049          7           7           7           7
# 1050          7           7           7           7
# 1688          7           7           7           7
# 2973          7           7           7           7
# 2257          6           6           6           6
# 3310          6           6           6           6
# 1827          6           6           6           6
#
# [4006 rows x 25 columns]

# %%
rp = pd.read_csv(ofile, sep=',')
rp['H-V'] = rp['HPen'] - rp['VPen']
rp['H-VYd'] = rp['HPenYd'] - rp['VPenYd']

cPen = rp.groupby('Penalty', as_index = False).count()
commonPens = cPen.sort_values('key', ascending = False).Penalty.head(8)
a = rp[rp['Penalty'].isin(commonPens)]

e = a[(a['Exp'] > 200)]
gByRef = e.groupby(['LastName','Penalty'], as_index = False).mean()
gByRef['NormH-VYd'] = gByRef['H-VYd'] / gByRef['Exp']


sns.set_style("whitegrid")
sns.set_context("notebook")
plt.figure(figsize=(16, 8))

#print gByRef[['LastName','Penalty','NormH-VYd']].sort_values('NormH-VYd', ascending = False)
g = sns.boxplot(x = 'Penalty', y = 'H-VYd', data = gByRef, saturation = 0.1, color = "Black")
g = sns.swarmplot(x = 'Penalty', y = 'H-VYd', data = gByRef)
#sns.violinplot(x = 'Penalty', y = 'H-VYd', data = gByRef)
#sns.stripplot(x = 'Penalty', y = 'H-VYd', data = gByRef)

g.axes.set_title('Average Home-Field Advantage By Penalty', fontsize=34,color="Black")

# %%
#def GetGameStats(row):
#    wk = row.
#print data
#g = nflgame.one(2011, 17, "NE", "BUF")
#print data.columns.values
#print data.head(5)
print e[(e['key'] == '09-11-2011-KC')]
#m = data.groupby(['team','game'], as_index = False).mean()
#print m.head(5)
print data[(data['game'] == '09/11/2011') & (data['player'] == 'J.Houston')]
print rp.columns.values
print rp[(rp['NDate'] == '09/11/2011') & (rp['Player'] == 'J.Houston')]

# %%
  


#Could 
def GetPlayersByGame(g)
    hp = g.players.filter(home = True)
    ap = g.players.filter(home = False)

print data.head(4)
#rd['key'] = rd.apply(MakeKey, axis=1)


def MatchRefToPenalty(b):
    #print b
    date = b.Date.split('/')
    print date
    d = str(date[2] + '-' + date[0] + '-' + date[1])
    print d
    m = rd.loc[(rd['Date'] == '2011-09-11')]
    print m['LastName','HTeam']



print rp.columns.values
rp['Exp'] = map(int, rp['Exp'])
e = rp[(rp['key'] > 200)]
e = e[(e['Position_x'] == 'Umpire')]
c = e.groupby('Penalty', as_index = False).count()
d = c[(c['key'] > 200)]
CommonPens = d.Penalty.unique()

p = e[e['Penalty'].isin(CommonPens)]
print p.shape

# %%
print data.shape
i = data.groupby(['Team','NDate'], as_index = False).count()
print i.head(10)
k = i.head(1)
print i.Year[0]
#print k.Week
#print k.Team

def FindGame(t):
    hg = nflgame.one(i.Year[0], i.Week[0], i.Team[0], '')
    vg = nflgame.one(i.Year[0], i.Week[0], '', i.Team[0])
    
    if (hg is None):
        homeTm =  False
        visTm = True
    elif (vg is None):
        homeTm = True
        visTm = False
    
    
#g = nflgame.one(2011, 17, 'ARI', 'ARI')
print game

# %%
print data.head(5)

# %%
a = [2, 5, 2]
b = [2, 5, 1]


print c
